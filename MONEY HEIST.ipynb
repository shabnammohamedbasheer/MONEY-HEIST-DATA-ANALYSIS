# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from IPython.display import Image

# %%
Image(filename="OIP.jfif")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 Image(filename="OIP.jfif")
#
# File C:\hello world\lib\site-packages\IPython\core\display.py:961, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     958 self.embed = embed if embed is not None else (url is None)
#     960 if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# --> 961     raise ValueError("Cannot embed the '%s' image format" % (self.format))
#     962 if self.embed:
#     963     self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the 'jfif' image format

# %%
heist=pd.read_csv("C:\hello world\data analytics\SELF\MY PROJECTS\MONEY HEIST\money heist - all seasons.csv",encoding="latin-1")

# %%
heist
# Out:
#     Season   Episode                               Name     On Air  Year  \
# 0         1         1              Efectuar lo acordado  02-May-17  2017
# 1         1         2              Imprudencias letales  09-May-17  2017
# 2         1         3                           Misfire  16-May-17  2017
# 3         1         4                  Caballo de Troya  23-May-17  2017
# 4         1         5              El día de la marmota  30-May-17  2017
# 5         1         6             La cálida Guerra Fría  06-Jun-17  2017
# 6         1         7         Refrigerada inestabilidad  13-Jun-17  2017
# 7         1         8                 Tú lo has buscado  20-Jun-17  2017
# 8         1         9       El que la sigue la consigue  27-Jun-17  2017
# 9         2         1          Se acabaron las máscaras  16-Oct-17  2017
# 10        2         2                La cabeza del plan  23-Oct-17  2017
# 11        2         3              Cuestión de eficacia  02-Nov-17  2017
# ...

# %%
heist.shape
# Out:
# (41, 8)

# %%
heist.size
# Out:
# 328

# %%
heist.describe()
# Out:
#          Season    Episode          Year       IMDB  Watch Time (minutes)
# count  41.000000  41.000000    41.000000  41.000000             41.000000
# mean    3.097561   4.707317  2018.951220   8.178049             49.292683
# std     1.496744   2.551900     1.642425   0.575114              6.716561
# min     1.000000   1.000000  2017.000000   7.100000             41.000000
# 25%     2.000000   3.000000  2017.000000   7.800000             43.000000
# 50%     3.000000   5.000000  2019.000000   8.300000             50.000000
# 75%     4.000000   7.000000  2020.000000   8.500000             53.000000
# max     5.000000  10.000000  2021.000000   9.500000             76.000000

# %%
heist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Season                41 non-null     int64
#  1   Episode               41 non-null     int64
#  2   Name                  41 non-null     object
#  3   On Air                41 non-null     object
#  4   Year                  41 non-null     int64
#  5   IMDB                  41 non-null     float64
#  6   Watch Time (minutes)  41 non-null     int64
#  7   Summary               41 non-null     object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 2.7+ KB

# %%
heist.dtypes
# Out:
# Season                    int64
# Episode                   int64
# Name                     object
# On Air                   object
# Year                      int64
# IMDB                    float64
# Watch Time (minutes)      int64
# Summary                  object
# dtype: object

# %%
heist.head()
# Out:
#    Season   Episode                   Name     On Air  Year  IMDB  \
# 0        1         1  Efectuar lo acordado  02-May-17  2017   8.4
# 1        1         2  Imprudencias letales  09-May-17  2017   8.4
# 2        1         3               Misfire  16-May-17  2017   8.2
# 3        1         4      Caballo de Troya  23-May-17  2017   8.3
# 4        1         5  El día de la marmota  30-May-17  2017   8.4
#
#    Watch Time (minutes)                                            Summary
# 0                    47  The Professor recruits a young female robber a...
# 1                    41  Hostage negotiator Raquel makes initial contac...
# 2                    50  Police grab an image of the face of one of the...
# 3                    51  Raquel is adversely affected by a personal cri...
# 4                    42  A sudden development in the investigation and ...

# %%
heist["Season "].value_counts()
#this tells us the number of episodes in each season
# Out:
# 5    10
# 1     9
# 3     8
# 4     8
# 2     6
# Name: Season , dtype: int64

# %%
heist["Year"].value_counts()
#the number of episodes released in each year
# Out:
# 2017    15
# 2021    10
# 2019     8
# 2020     8
# Name: Year, dtype: int64

# %%
sns.boxplot(heist,x="Season ",y="IMDB")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
heist["IMDB"].unique()
# Out:
# array([8.4, 8.2, 8.3, 8.7, 8.6, 8.5, 8.8, 9.4, 8.1, 9.5, 7.5, 7.2, 7.1,
#        7.7, 7.6, 7.3, 7.8, 8. ])

# %%
high_rate=heist[heist["IMDB"]>=9.5]
high_rate
#episode 8 in season 3 is the episode with highest rating
# Out:
#     Season   Episode     Name     On Air  Year  IMDB  Watch Time (minutes)  \
# 22        3         8  Astray  19-Jul-21  2019   9.5                    60
#
#                                               Summary
# 22  Tokyo attempts to drown her sorrows. Sierra us...

# %%
high_rate["Summary"][22]
#this is the summary of the highest rating episode
# Out:
# 'Tokyo attempts to drown her sorrows. Sierra uses personal tactics to target a vulnerable Nairobi, while Suárez continues to hunt down Raquel.'

# %% [markdown]
# ### total watch hours in each season

# %%
heist[["Season ","Watch Time (minutes)",]].groupby("Season ").sum()
# Out:
#          Watch Time (minutes)
# Season
# 1                         406
# 2                         279
# 3                         391
# 4                         402
# 5                         543

# %% [markdown]
# ### average imdb rating and watch time on  year basis

# %%
heist[["IMDB","Watch Time (minutes)","Year"]].groupby("Year").mean()
# Out:
#           IMDB  Watch Time (minutes)
# Year
# 2017  8.546667             45.666667
# 2019  8.450000             48.875000
# 2020  7.612500             50.250000
# 2021  7.860000             54.300000

# %%
heist.groupby("Year").count()
# Out:
#       Season   Episode   Name  On Air  IMDB  Watch Time (minutes)  Summary
# Year
# 2017       15        15    15      15    15                    15       15
# 2019        8         8     8       8     8                     8        8
# 2020        8         8     8       8     8                     8        8
# 2021       10        10    10      10    10                    10       10

# %%
heist[["Year","Watch Time (minutes)"]].groupby("Year").sum()
# Out:
#       Watch Time (minutes)
# Year
# 2017                   685
# 2019                   391
# 2020                   402
# 2021                   543

# %%
#we are considering certain columns to make the data understandable
#in the above data if we check with the count , count of season per year is not correct as there is only 5 season

# %%
heist[heist["IMDB"]>9]
# Out:
#     Season   Episode         Name     On Air  Year  IMDB  \
# 14        2         6  Bella ciao  23-Nov-17  2017   9.4
# 22        3         8      Astray  19-Jul-21  2019   9.5
#
#     Watch Time (minutes)                                            Summary
# 14                    43  After confessing a long-held secret, Moscow lo...
# 22                    60  Tokyo attempts to drown her sorrows. Sierra us...

# %%
#the best rated episodes

# %%
heist[["Year","Watch Time (minutes)"]].groupby("Year").count()
# Out:
#       Watch Time (minutes)
# Year
# 2017                    15
# 2019                     8
# 2020                     8
# 2021                    10

# %%
#in 2018 there were no episodes
#in 2019 and 2020 were the least amount of episodes

# %%
#which season show had max watch hours
heist[["Watch Time (minutes)","Season "]].groupby("Season ").sum()
#season 5 had max watch minutes
# Out:
#          Watch Time (minutes)
# Season
# 1                         406
# 2                         279
# 3                         391
# 4                         402
# 5                         543

# %%
#how many episodes in each year
heist[["Season ","Episode "]].groupby("Season ").count()
# season 5 have the most number of episode
# Out:
#          Episode
# Season
# 1               9
# 2               6
# 3               8
# 4               8
# 5              10

# %%
#which is the smallest episode

# %%
heist.columns
# Out:
# Index(['Season ', 'Episode ', 'Name', 'On Air', 'Year', 'IMDB',
#        'Watch Time (minutes)', 'Summary'],
#       dtype='object')

# %%
heist[["Season ","Episode ","Watch Time (minutes)"]].min()
# Out:
# Season                   1
# Episode                  1
# Watch Time (minutes)    41
# dtype: int64

# %%
heist[["Season ","Episode ","Watch Time (minutes)"]].max()
# Out:
# Season                   5
# Episode                 10
# Watch Time (minutes)    76
# dtype: int64

# %%
#episode 1 in season 1 was the smallest
#episode 5 in season 5 was the biggest

# %%
heist["IMDB"].nunique()
#there 18 different rating values in all 40 episode
# Out:
# 18

# %%
#avg watch time for each episode
heist["Watch Time (minutes)"].mean()
# Out:
# 49.292682926829265

# %%
heist[["IMDB","Season "]].groupby("Season ").mean()
#imdb average rating for each season
# Out:
#              IMDB
# Season
# 1        8.366667
# 2        8.816667
# 3        8.450000
# 4        7.612500
# 5        7.860000

# %%
heist["IMDB"].max()
# Out:
# 9.5

# %%
heist["IMDB"].min()
# Out:
# 7.1

# %%
heist[heist["IMDB"]<=7.5]
#the below episodes below show the least rating in imdb
# Out:
#     Season   Episode                               Name     On Air  Year  \
# 23        4         1                         Game Over  03-Apr-20  2020
# 24        4         2                  Berlin's Wedding  03-Apr-20  2020
# 25        4         3                    Anatomy Lesson  03-Apr-20  2020
# 27        4         5                 5 Minutes Earlier  03-Apr-20  2020
# 31        5         1               The End of the Road  03-Sep-21  2021
# 32        5         2  Do You Believe in Reincarnation?  03-Sep-21  2021
# 33        5         3  Welcome to the Spectacle of Life  03-Sep-21  2021
# 36        5         6                      Escape Valve  03-Dec-21  2021
#
#     IMDB  Watch Time (minutes)  \
# 23   7.5                    54
# 24   7.2                    46
# 25   7.1                    43
# 27   7.2                    44
# 31   7.5                    49
# 32   7.1                    52
# 33   7.3                    50
# 36   7.3                    53
#
# ...

# %%
heist[["Watch Time (minutes)","Year"]].groupby("Year").mean()
#average duration of movies released each year
# Out:
#       Watch Time (minutes)
# Year
# 2017             45.666667
# 2019             48.875000
# 2020             50.250000
# 2021             54.300000

# %%
heist[["Episode ","IMDB"]].groupby("IMDB").count()
#the data below shows how many episodes are there under each rating
# Out:
#       Episode
# IMDB
# 7.1          2
# 7.2          2
# 7.3          2
# 7.5          2
# 7.6          1
# 7.7          1
# 7.8          1
# 8.0          1
# 8.1          3
# 8.2          2
# 8.3          6
# 8.4          7
# 8.5          3
# 8.6          2
# 8.7          1
# 8.8          3
# 9.4          1
# 9.5          1

# %%
heist.loc[:, 'Year'].sort_values().reset_index()
#we can see the episode which were released which year
# Out:
#     index  Year
# 0       0  2017
# 1      14  2017
# 2      13  2017
# 3      12  2017
# 4      11  2017
# 5      10  2017
# 6       9  2017
# 7       8  2017
# 8       6  2017
# 9       5  2017
# 10      4  2017
# 11      3  2017
# 12      2  2017
# 13      1  2017
# 14      7  2017
# 15     21  2019
# 16     22  2019
# 17     19  2019
# 18     20  2019
# 19     17  2019
# 20     16  2019
# 21     15  2019
# 22     18  2019
# 23     30  2020
# 24     28  2020
# 25     27  2020
# 26     29  2020
# 27     25  2020
# 28     24  2020
# 29     23  2020
# 30     26  2020
# 31     39  2021
# 32     31  2021
# 33     32  2021
# 34     33  2021
# 35     34  2021
# 36     35  2021
# 37     36  2021
# 38     37  2021
# 39     38  2021
# 40     40  2021

# %%
heist.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_18120\4050765296.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heist.corr()
#                        Season   Episode       Year      IMDB  \
# Season                1.000000  0.105842  0.978272 -0.526029
# Episode               0.105842  1.000000  0.139662  0.327680
# Year                  0.978272  0.139662  1.000000 -0.580784
# IMDB                 -0.526029  0.327680 -0.580784  1.000000
# Watch Time (minutes)  0.496941  0.301214  0.490836  0.051539
#
#                       Watch Time (minutes)
# Season                            0.496941
# Episode                           0.301214
# Year                              0.490836
# IMDB                              0.051539
# Watch Time (minutes)              1.000000

# %%
#season and year is showinh high +ve relation which means that as year increased season also incresd
#imdb is showing a small -ve relation with year as year increased the rating decresd
#year and watch time shows a small +ve relatin
#season and imdb is showing small _ve relation which shows as the season incresd rating dec
#season and year shows small +ve relation to watch time which shows as year and seasn inc wat tim inc

# %%
sns.barplot(x="Year",y="Watch Time (minutes)",data=heist)
# Out:
# <Axes: xlabel='Year', ylabel='Watch Time (minutes)'>

# %%
sns.barplot(x="Year",y="Watch Time (minutes)",data=heist,hue="Season ")
# Out:
# <Axes: xlabel='Year', ylabel='Watch Time (minutes)'>

# %%
sns.boxplot(x="Year",y="Watch Time (minutes)",data=heist,hue="Season ")
# Out:
# <Axes: xlabel='Year', ylabel='Watch Time (minutes)'>

# %%
#the above graph shows the season released in each year wrto time of episode
#we can check with the percentile medians and all using box plot

# %%
heist["IMDB"].nlargest()
# Out:
# 22    9.5
# 14    9.4
# 11    8.8
# 12    8.8
# 13    8.8
# Name: IMDB, dtype: float64

# %%
heist.describe().T
# Out:
#                       count         mean       std     min     25%     50%  \
# Season                 41.0     3.097561  1.496744     1.0     2.0     3.0
# Episode                41.0     4.707317  2.551900     1.0     3.0     5.0
# Year                   41.0  2018.951220  1.642425  2017.0  2017.0  2019.0
# IMDB                   41.0     8.178049  0.575114     7.1     7.8     8.3
# Watch Time (minutes)   41.0    49.292683  6.716561    41.0    43.0    50.0
#
#                          75%     max
# Season                   4.0     5.0
# Episode                  7.0    10.0
# Year                  2020.0  2021.0
# IMDB                     8.5     9.5
# Watch Time (minutes)    53.0    76.0

# %%
sns.barplot(x="Name",y="Watch Time (minutes)",data=heist.sort_values("Watch Time (minutes)"))
plt.title("episode with time")
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x="Name",y="Watch Time (minutes)",data=heist,hue="Year")
plt.title("episode with time")
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
